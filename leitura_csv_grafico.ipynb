# %%
import matplotlib.pyplot as plt
import pandas as pd
from astropy import units as u
from astropy.coordinates import SkyCoord

# %reload_ext autoreload
# %autoreload 2

# %%
csvdata = pd.read_csv("regiao_escolhida.csv", sep=";")

# %%
csvdata_1 = pd.read_csv("regiao_escolhida_2.csv", sep=";")

# %%
csvdata
# Out:
#        coadd_object_id         ra        dec  flags_g  mag_auto_g_dered  \
# 0           1138842506  17.082053 -36.198605        0         26.359207
# 1           1138842734  17.097314 -36.200732        0         24.670666
# 2           1138842361  17.090352 -36.197428        0         23.093044
# 3           1138842901  17.117750 -36.202505        0         24.730970
# 4           1138842946  17.099823 -36.202932        0         25.112797
# ...                ...        ...        ...      ...               ...
# 37322       1150896218  18.481485 -35.212624        0         25.241669
# 37323       1150895864  18.488418 -35.210709        2         22.788883
# 37324       1150894893  18.475870 -35.200470        0         26.232893
# 37325       1150894914  18.483720 -35.200761        0         25.925808
# 37326       1150895472  18.497418 -35.205736        0         24.977819
#
#        mag_auto_r_dered  mag_auto_i_dered  magerr_auto_g  magerr_auto_r  \
# 0             25.419777         24.981171       0.503872       0.260277
# 1             23.581909         21.787003       0.215075       0.097765
# 2             21.656044         20.117279       0.055281       0.018205
# 3             23.414288         22.755047       0.198424       0.073949
# 4             24.607725         24.261232       0.196757       0.156388
# ...                 ...               ...            ...            ...
# 37322         25.398832         25.046328       0.172784       0.258969
# 37323         21.379061         20.038218       0.043070       0.014765
# 37324         25.727058         24.991709       0.422247       0.336679
# 37325         25.127954         24.412809       0.512891       0.312952
# 37326         24.295557         24.708206       0.244048       0.159423
#
#        magerr_auto_i
# 0           0.321591
# 1           0.035365
# 2           0.008220
# 3           0.080810
# 4           0.223328
# ...              ...
# 37322       0.366447
# 37323       0.008339
# 37324       0.351574
# 37325       0.332331
# 37326       0.495332
#
# [37327 rows x 10 columns]

# %%
csvdata_1
# Out:
#        coadd_object_id         ra        dec  flags_g  mag_auto_g_dered  \
# 0           1146188971  17.744372 -36.154223        0         25.994610
# 1           1146189190  17.749662 -36.156164        0         26.674141
# 2           1146188795  17.755407 -36.158653        0         17.308920
# 3           1146189034  17.756541 -36.154759        3         24.219757
# 4           1146188770  17.748762 -36.152379        0         28.102932
# ...                ...        ...        ...      ...               ...
# 18268       1145373026  18.226016 -35.242279        0         24.870453
# 18269       1145372343  18.221280 -35.236103        0         25.129591
# 18270       1150899959  18.245832 -35.247096        0         25.391972
# 18271       1150899898  18.252611 -35.246540        0         25.871826
# 18272       1150900030  18.257445 -35.247973        0         24.770174
#
#        mag_auto_r_dered  mag_auto_i_dered  magerr_auto_g  magerr_auto_r  \
# 0             25.414762         25.576010       0.312995       0.243127
# 1             25.692621         25.771229       0.747532       0.402340
# 2             16.644096         16.415173       0.000582       0.000413
# 3             23.974953         23.828325       0.100813       0.108047
# 4             99.000000         26.196224       2.206546      99.000000
# ...                 ...               ...            ...            ...
# 18268         24.508133         24.319130       0.158558       0.147066
# 18269         23.775654         23.367079       0.218710       0.081458
# 18270         24.310572         26.220100       0.374797       0.177057
# 18271         25.349840         25.512899       0.308656       0.243886
# 18272         23.885508         23.987997       0.216208       0.122336
#
#        magerr_auto_i
# 0           0.526628
# 1           0.840898
# 2           0.000452
# 3           0.170799
# 4           0.940894
# ...              ...
# 18268       0.244618
# 18269       0.110167
# 18270       2.034148
# 18271       0.560801
# 18272       0.272525
#
# [18273 rows x 10 columns]

# %%
csvdata.head()
# Out:
#     object_id         ra        dec  flags_g      mag_g      mag_r      mag_i  \
# 0  1138842506  17.082053 -36.198605        0  26.359207  25.419777  24.981171
# 1  1138842734  17.097314 -36.200732        0  24.670666  23.581909  21.787003
# 2  1138842361  17.090352 -36.197428        0  23.093044  21.656044  20.117279
# 3  1138842901  17.117750 -36.202505        0  24.730970  23.414288  22.755047
# 4  1138842946  17.099823 -36.202932        0  25.112797  24.607725  24.261232
#
#       err_g     err_r     err_i
# 0  0.503872  0.260277  0.321591
# 1  0.215075  0.097765  0.035365
# 2  0.055281  0.018205  0.008220
# 3  0.198424  0.073949  0.080810
# 4  0.196757  0.156388  0.223328

# %%
csvdata_1.head()
# Out:
#     object_id         ra        dec  flags_g      mag_g      mag_r      mag_i  \
# 0  1146188971  17.744372 -36.154223        0  25.994610  25.414762  25.576010
# 1  1146189190  17.749662 -36.156164        0  26.674141  25.692621  25.771229
# 2  1146188795  17.755407 -36.158653        0  17.308920  16.644096  16.415173
# 3  1146189034  17.756541 -36.154759        3  24.219757  23.974953  23.828325
# 4  1146188770  17.748762 -36.152379        0  28.102932  99.000000  26.196224
#
#       err_g      err_r     err_i
# 0  0.312995   0.243127  0.526628
# 1  0.747532   0.402340  0.840898
# 2  0.000582   0.000413  0.000452
# 3  0.100813   0.108047  0.170799
# 4  2.206546  99.000000  0.940894

# %% [markdown]
# Distribuição espacial

# %%
# %%time
plt.figure(figsize=[10,5], dpi=300)
plt.suptitle("Estrelas no DR2", fontsize=14)
plt.subplot(1,2,1)
plt.plot(csvdata.ra, csvdata.dec, 'k.', alpha=0.1)
plt.xlabel("R.A. (deg)", fontsize=14)
plt.ylabel("Dec. (deg)", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.subplot(1,2,2)
plt.plot(csvdata_1.ra, csvdata_1.dec, 'k.', alpha=0.1)
plt.xlabel("R.A. (deg)", fontsize=14)
plt.ylabel("Dec. (deg)", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
# Out:
# CPU times: user 192 ms, sys: 138 ms, total: 329 ms
# Wall time: 366 ms

# %% [markdown]
# Mapa de densidade

# %%
# %%time
plt.figure(figsize=[12,5], dpi=300)
plt.suptitle("Estrelas no DES DR2", fontsize=14)
plt.subplot(1,2,1)
plt.hist2d(csvdata.ra, csvdata.dec, bins=50)
plt.xlabel("R.A. (deg)", fontsize=14)
plt.ylabel("Dec. (deg)", fontsize=14)
plt.colorbar(label="Densidade de Pontos")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.subplot(1,2,2)
plt.hist2d(csvdata_1.ra, csvdata_1.dec, bins=50)
plt.xlabel("R.A. (deg)", fontsize=14)
plt.ylabel("Dec. (deg)", fontsize=14)
plt.colorbar(label="Densidade de Pontos")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
# Out:
# CPU times: user 342 ms, sys: 203 ms, total: 545 ms
# Wall time: 575 ms

# %% [markdown]
# Grafico CMD

# %%
new_columns = {"coadd_object_id": "object_id",
               "mag_auto_g_dered": "mag_g",
               "mag_auto_r_dered": "mag_r",
               "mag_auto_i_dered": "mag_i",
               "magerr_auto_g": "err_g", 
               "magerr_auto_r": "err_r", 
               "magerr_auto_i": "err_i"}

csvdata.rename(columns=new_columns, inplace=True)

# %%
csvdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37327 entries, 0 to 37326
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   object_id  37327 non-null  int64
#  1   ra         37327 non-null  float64
#  2   dec        37327 non-null  float64
#  3   flags_g    37327 non-null  int64
#  4   mag_g      37327 non-null  float64
#  5   mag_r      37327 non-null  float64
#  6   mag_i      37327 non-null  float64
#  7   err_g      37327 non-null  float64
#  8   err_r      37327 non-null  float64
#  9   err_i      37327 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 2.8 MB

# %%
csvdata["gmr"] = csvdata.mag_g - csvdata.mag_r

# %%
csvdata.head()
# Out:
#     object_id         ra        dec  flags_g      mag_g      mag_r      mag_i  \
# 0  1138842506  17.082053 -36.198605        0  26.359207  25.419777  24.981171
# 1  1138842734  17.097314 -36.200732        0  24.670666  23.581909  21.787003
# 2  1138842361  17.090352 -36.197428        0  23.093044  21.656044  20.117279
# 3  1138842901  17.117750 -36.202505        0  24.730970  23.414288  22.755047
# 4  1138842946  17.099823 -36.202932        0  25.112797  24.607725  24.261232
#
#       err_g     err_r     err_i       gmr
# 0  0.503872  0.260277  0.321591  0.939430
# 1  0.215075  0.097765  0.035365  1.088757
# 2  0.055281  0.018205  0.008220  1.437000
# 3  0.198424  0.073949  0.080810  1.316683
# 4  0.196757  0.156388  0.223328  0.505072

# %%
csvdata.query("flags_g < 4  & mag_g != 99. & mag_r != 99. & mag_i != 99. ", inplace=True)

# %%
csvdata.count()
# Out:
# object_id    35290
# ra           35290
# dec          35290
# flags_g      35290
# mag_g        35290
# mag_r        35290
# mag_i        35290
# err_g        35290
# err_r        35290
# err_i        35290
# gmr          35290
# dtype: int64

# %%
csvdata.describe()
# Out:
#           object_id            ra           dec       flags_g         mag_g  \
# count  3.529000e+04  35290.000000  35290.000000  35290.000000  35290.000000
# mean   1.142860e+09     17.512686    -35.702344      0.275971     24.847864
# std    4.293036e+06      0.567124      0.293337      0.808568      2.016811
# min    1.132663e+09     16.500017    -36.203974      0.000000     14.031293
# 25%    1.138454e+09     17.033877    -35.956581      0.000000     24.410357
# 50%    1.144753e+09     17.522346    -35.707548      0.000000     25.236073
# 75%    1.144808e+09     18.001370    -35.439301      0.000000     25.901436
# max    1.151529e+09     18.499919    -35.200267      3.000000     36.565079
#
#               mag_r         mag_i         err_g         err_r         err_i  \
# count  35290.000000  35290.000000  35290.000000  35290.000000  35290.000000
# mean      24.118428     23.806170      1.107972      0.270513      0.482014
# std        2.022707      2.204404     43.511118      1.084282      4.648517
# min       13.503300     13.283485      0.000197      0.000217      0.000248
# 25%       23.761253     23.290624      0.139767      0.104546      0.130846
# 50%       24.737851     24.548791      0.249667      0.200350      0.306516
# 75%       25.291436     25.136128      0.434330      0.301381      0.480212
# max       32.091442     32.939766   6529.541504    153.414581    587.774475
#
#                 gmr
# count  35290.000000
# mean       0.729435
# std        0.803024
# min       -4.656290
# 25%        0.223425
# 50%        0.602212
# 75%        1.215085
# max       10.311960

# %%
plt.figure(figsize=[7,5])
plt.title("CMD - Estrelas no DES DR2", fontsize=14)
plt.hexbin(csvdata.gmr, csvdata.mag_r, gridsize=500, bins='log') #Essa linha cria um gráfico hexbin usando Matplotlib, 
#que é particularmente útil para visualizar a densidade de pontos de dados em um espaço bidimensional.
plt.xlabel("$g - r$", fontsize=14)
plt.ylabel("$g$", fontsize=14)
plt.colorbar(label="Densidade de Pontos")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlim(-1.5,2.5)
plt.ylim(30,14)
plt.tight_layout()
